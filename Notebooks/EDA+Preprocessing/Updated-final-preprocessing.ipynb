# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/Users/abhaylal/Desktop/DeepLearning/ResumeParser-Recommender/Data/final.zip')

# %%
df
# Out:
#        Unnamed: 0                                               Text  \
# 0               0  Database AdministratorDatabase AdministratorDa...
# 1               1  Database AdministratorSQL Microsoft PowerPoint...
# 2               2  Oracle Database AdministratorOracle Database A...
# 3               3  Amazon Redshift Administrator ETL Developer Bu...
# 4               4  Scrum MasterOracle Database Administrator Scru...
# ...           ...                                                ...
# 29778       29778  ServiceNow DeveloperServiceNow DeveloperServic...
# 29779       29779  Android DeveloperAndroid DeveloperRoute Planne...
# 29780       29780  UI DeveloperUI WEB DeveloperUI DeveloperUI Dev...
# 29781       29781  Web DeveloperJavascriptPHPFront EndWordpressWe...
# 29782       29782  Sr Software EngineerDevOps ManagerWeb Develope...
#
#                                                    Label  Software_Developer  \
# 0                            [b'Database_Administrator']                   0
# 1                            [b'Database_Administrator']                   0
# 2                            [b'Database_Administrator']                   0
# 3                            [b'Database_Administrator']                   0
# 4                            [b'Database_Administrator']                   0
# ...                                                  ...                 ...
# 29778  [b'Java_Developer\n', b'Web_Developer\n', b'So...                   1
# 29779        [b'Web_Developer\n', b'Software_Developer']                   1
# 29780  [b'Software_Developer\n', b'Front_End_Develope...                   1
# 29781        [b'Web_Developer\n', b'Software_Developer']                   1
# 29782        [b'Software_Developer\n', b'Web_Developer']                   1
#
#        Database_Administrator  Systems_Administrator  Project_manager  \
# 0                           1                      0                0
# 1                           1                      0                0
# 2                           1                      0                0
# 3                           1                      0                0
# 4                           1                      0                0
# ...                       ...                    ...              ...
# 29778                       0                      0                0
# 29779                       0                      0                0
# 29780                       0                      0                0
# 29781                       0                      0                0
# 29782                       0                      0                0
#
#        Web_Developer  Network_Administrator  Security_Analyst  \
# 0                  0                      0                 0
# 1                  0                      0                 0
# 2                  0                      0                 0
# 3                  0                      0                 0
# 4                  0                      0                 0
# ...              ...                    ...               ...
# 29778              1                      0                 0
# 29779              1                      0                 0
# 29780              1                      0                 0
# 29781              1                      0                 0
# 29782              1                      0                 0
#
#        Python_Developer  Java_Developer  Front_End_Developer
# 0                     0               0                    0
# 1                     0               0                    0
# 2                     0               0                    0
# 3                     0               0                    0
# 4                     0               0                    0
# ...                 ...             ...                  ...
# 29778                 0               1                    0
# 29779                 0               0                    0
# 29780                 0               0                    1
# 29781                 0               0                    0
# 29782                 0               0                    0
#
# [29783 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29783 entries, 0 to 29782
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              29783 non-null  int64
#  1   Text                    29783 non-null  object
#  2   Label                   29783 non-null  object
#  3   Software_Developer      29783 non-null  int64
#  4   Database_Administrator  29783 non-null  int64
#  5   Systems_Administrator   29783 non-null  int64
#  6   Project_manager         29783 non-null  int64
#  7   Web_Developer           29783 non-null  int64
#  8   Network_Administrator   29783 non-null  int64
#  9   Security_Analyst        29783 non-null  int64
#  10  Python_Developer        29783 non-null  int64
#  11  Java_Developer          29783 non-null  int64
#  12  Front_End_Developer     29783 non-null  int64
# dtypes: int64(11), object(2)
# memory usage: 3.0+ MB

# %%
def remove_digits(text):
    output = ''.join(c for c in text if not c.isdigit())
    return output

# %%
df['Text'] = df['Text'].apply(remove_digits)

# %%
df['Text'][9]
# Out:
# 'Oracle Database AdministratorDatabase Administrator DeveloperJunior DBADATABASEORACLEPLSQLSQLENCRYPTIONRMANLINUXSHELL SCRIPTINGUNIXUNIX SHELLETLINFORMATICABASHSCRIPTINGSECURITYCAPACITY PLANNINGPERFORMANCE TUNINGOEMCLONINGARCHITECTUREDBAOracle DbaSql ServerOracle Database Administrator Oracle Database Administrator Oracle Database Administrator Uber Technologies Inc Greenbelt MD Im accomplished certified ORACLE Database Administrator IT expert seven years experience extensive knowledge proficiency database design monitoring performance tuning migration upgrades backup recovery cloning replication security implementations Oracle RDBMS I skilled assortment technologies including Oracle g g c c MS SQL Server I possess exceptional analytical verbal written organizational abilities Im proven team player motivational style solid reputation building retaining highly motivated teams development innovative solutions I achiever successfully manage multiple priorities perform extensively pressure Im proactive learner willing update skills new technologies improve productivity workplace Authorized work US employer Work Experience Oracle Database Administrator Uber Technologies Inc November  Present Constructing database security policy passwords privileges user profiles Transparent Data EncryptionTDE encrypt tables tablespaces implemented auditing policies data redaction data masking Designing backup strategies following company SLA execution backup schedule physical logical backups Rman Datapump utilities respectively Used block change tracking BCT reducing backup time hrs mins Resolved space issues backup optimization reducing storage costs  Upgrading databases g c Supporting daily administration monitoring tuning troubleshooting single instance UNIXLinux Database sizes range GB TB Monitoring AWR ADDM ASH Alert log dynamic performance views DBMSSTATS Trace Files System Event Logs unusual events took appropriate action according company policies incident reports Implementing table index partitioning materialized views minimize DB time increase disk load balancing improve query speed enable faster parallel query Cloning schemas objects databases new server exports g database imported g DATA PUMP Applied Oracles quarterly Critical Patch Update CPU PSU application Opatch utility install test deploy patches database instances Implementing tuning maintaining Oracle database OEM Capacity planning meet demands dynamic aspects storage memory databases Reconciled functional technical problems research training workshops achieving  increase satisfaction rate database end users Developing Standard Operating Procedures SOPs data extraction weekly activity report Database Administrator Developer SYSCO March  October  Installed configured Oracle g g servers created databases Linux environments Researched tested recommendations data validation tools Established implemented backuprecovery patch scheduling exported imported databases frequently development test environments archiving purposes Generated shell scripts developers automate maintenance backup jobs Created databases Entity Relational Diagrams ERD Forward Engineering UML Unified Modeling Language Part team conducted database migration g upgrade c Oracle Datapump DBUA respectively Cloned databases testing RMAN DATAPUMP utilities database sizes Administering Physical Standby databases high availability disaster recovery solution DATA GUARD Expert working PLSQL including Procedures Functions Cursors Triggers Providing administrative support maintenance Oracle g c installations database creation database security database optimization tuning Created tracked closed service tickets REMEDY ticketing system developed defect prevention process including limited root cause analysis corrective action Controlled databases high alertness ensure peak performance stability reliability availability Configure manage ASM instances Oracle g c Resolved locking issues inconsistencies assisted batch processes Assist ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Text', 'Label', 'Software_Developer',
#        'Database_Administrator', 'Systems_Administrator', 'Project_manager',
#        'Web_Developer', 'Network_Administrator', 'Security_Analyst',
#        'Python_Developer', 'Java_Developer', 'Front_End_Developer'],
#       dtype='object')

# %%
df.drop(columns='Unnamed: 0',axis=1,inplace=True)

# %%
df.to_csv('res_data.csv')
